# %%
from matplotlib import pyplot as plt
 
from src.problem import unimodal
from src.ioas.AHA import AHA

# %%
sphere_solution = AHA(problem=unimodal.SphereBenchmark(dim=2), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[-1.99713308e-112 -1.55623134e-111],
#                  best_fitness=2.4617413958273962e-222,
#                  start_time=2023-10-31 21:28:56,
#                  end_time=2023-10-31 21:28:57>

# %%
plt.plot(sphere_solution.iteration_curve)
