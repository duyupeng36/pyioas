# %%
from matplotlib import pyplot as plt
 
from src.problem import unimodal
from src.ioas.AHA import AHA

# %%
sphere_solution = AHA(problem=unimodal.SphereBenchmark(dim=50), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[ 1.18351879e-112 -2.85412395e-109 -9.75264272e-111 -4.19968576e-108
#   3.70022481e-109 -1.96655808e-109 -2.81324077e-109 -1.53757355e-114
#  -6.01491003e-109 -2.00363063e-108 -4.01436711e-113  2.40879857e-116
#   9.93806762e-111 -2.26490267e-110 -6.66401943e-109  7.03947289e-112
#   7.72491200e-112 -9.94365402e-110 -3.11257448e-109 -1.95237799e-111
#   5.17594853e-113 -7.64008873e-112  3.20879991e-109 -3.72536332e-108
#   3.14678787e-111 -1.57351815e-115 -1.14793452e-112  1.82843239e-108
#   7.14931313e-110  3.45069277e-111 -2.59716798e-110  9.48394306e-112
#   8.42474169e-108 -9.49706473e-109 -9.81088061e-114  4.91335526e-111
#  -4.91190539e-116 -4.79036384e-113  2.76284503e-111 -2.57623634e-111
#   5.59673474e-109  3.07891176e-108  2.81858692e-111 -1.36126836e-109
#   2.88983030e-108  1.54333414e-107 -2.74233595e-108  1.86735252e-107
#  -2.04704515e-108 -1.75018208e-112],
# ...

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
