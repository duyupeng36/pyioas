# %%
from matplotlib import pyplot as plt
 
from src.problem import SphereBenchmark
from src.ioas import PSO

# %%
sphere_solution = PSO(problem=SphereBenchmark(dim=50), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[ 0.01567537 -0.0205356   0.0129208   0.00069103  0.02519369  0.01226205
#   0.01658194  0.01989482  0.02527873  0.0060213  -0.00158176 -0.05454295
#  -0.00058139  0.00697482  0.00205226 -0.01137959 -0.00131751 -0.02566864
#  -0.00432619  0.01547972 -0.00570872  0.09498207  0.01162676  0.03391626
#  -0.00883686 -0.00374184  0.01294485  0.00645248 -0.00522597  0.00201341
#   0.00636015  0.04696235  0.00308348 -0.02465396  0.01414047 -0.01020696
#  -0.01770871 -0.00052041 -0.00230181 -0.01861236 -0.00219996  0.0019159
#  -0.00058412  0.01191582 -0.00129264  0.00518088 -0.02029714  0.00064514
#   0.00397826 -0.0183757 ],
#                  best_fitness=0.02249558015194151,
#                  start_time=2023-11-02 22:57:47,
#                  end_time=2023-11-02 22:57:48>

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
