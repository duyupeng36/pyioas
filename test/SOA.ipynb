# %%
from matplotlib import pyplot as plt
 
from src.problem import SphereBenchmark
from src.ioas.SOA import SOA

# %%
sphere_solution = SOA(problem=SphereBenchmark(dim=50), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[-4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21 -4.8102423e-21 -4.8102423e-21
#  -4.8102423e-21 -4.8102423e-21],
#                  best_fitness=1.1569215512555373e-39,
#                  start_time=2023-11-02 22:58:39,
# ...

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
