# %%
from matplotlib import pyplot as plt
 
from src.problem import unimodal
from src.ioas.SOA import SOA

# %%
sphere_solution = SOA(problem=unimodal.SphereBenchmark(dim=50), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19 4.20160752e-19 4.20160752e-19
#  4.20160752e-19 4.20160752e-19],
#                  best_fitness=8.826752861494164e-36,
#                  start_time=2023-11-02 13-23-37,
# ...

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
