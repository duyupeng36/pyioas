# %%
from matplotlib import pyplot as plt
 
from src.problem import unimodal
from src.ioas.SOA import SOA

# %%
sphere_solution = SOA(problem=unimodal.SphereBenchmark(dim=50), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[-1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22 -1.66656296e-22 -1.66656296e-22
#  -1.66656296e-22 -1.66656296e-22],
#                  best_fitness=1.3887160471854742e-42,
#                  start_time=2023-11-02 14-14-01,
#                  end_time=2023-11-02 14-14-01>

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
