# %%
from matplotlib import pyplot as plt
 
from src.problem import SphereBenchmark
from src.ioas import HHO

# %%
sphere_solution = HHO(problem=SphereBenchmark(dim=30), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[-6.22082621e-57  1.92332612e-56 -2.28493697e-56 -1.93166919e-56
#  -5.58657043e-56 -1.47952470e-56  1.16182681e-55 -2.36890713e-56
#  -1.04776325e-56 -5.19740719e-57 -3.49475067e-58 -4.75342204e-57
#   2.46671071e-56 -8.42475542e-56 -1.08460745e-56 -4.16373190e-56
#   2.41781576e-59 -2.16818457e-57 -1.48584215e-59 -6.57088448e-57
#   1.38696989e-58 -1.79692769e-56 -6.36737223e-57 -1.19713703e-56
#   2.05350668e-57 -2.49955844e-59 -7.36381727e-58 -1.44799952e-56
#   5.40430842e-57  4.29197963e-57],
#                  best_fitness=2.92369475353691e-110,
#                  start_time=2023-11-02 22:57:30,
#                  end_time=None>

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
