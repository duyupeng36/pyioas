# %%
from matplotlib import pyplot as plt
 
from src.problem import SphereBenchmark
from src.ioas import GWO

# %%
sphere_solution = GWO(problem=SphereBenchmark(dim=30), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[-5.11225581e-20  4.99815972e-20  4.43907968e-20  5.42408108e-20
#   5.29075041e-20 -5.69638164e-20 -5.39887887e-20  5.08520368e-20
#   4.68824391e-20 -4.82428970e-20 -4.20412857e-20 -5.58952394e-20
#  -5.53235526e-20  4.90614487e-20 -4.85022156e-20  5.35958593e-20
#  -4.57446320e-20  4.60178815e-20  4.90592851e-20  5.37156721e-20
#  -5.24091110e-20 -5.16710879e-20  5.63678057e-20 -5.89620969e-20
#   5.95961908e-20  4.64618676e-20  6.00804426e-20 -4.97231449e-20
#  -5.20256680e-20  4.64089063e-20],
#                  best_fitness=7.990467049799523e-38,
#                  start_time=2023-11-02 22:57:14,
#                  end_time=2023-11-02 22:57:15>

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
