# %%
from matplotlib import pyplot as plt
 
from src.problem import unimodal
from src.ioas import GWO

# %%
sphere_solution = GWO(problem=unimodal.SphereBenchmark(dim=30), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[ 2.26677639e-21  2.17564980e-21  2.32366441e-21  2.28834602e-21
#  -2.11520941e-21  2.14763523e-21 -2.42593638e-21 -2.60797235e-21
#  -2.16419427e-21 -2.47378633e-21  2.73414169e-21 -2.39760087e-21
#  -2.01322817e-21 -2.42672081e-21  2.27808873e-21 -2.38633794e-21
#   2.32199688e-21  2.48534361e-21 -2.45493396e-21 -2.43120007e-21
#   2.23015818e-21  2.48177299e-21 -2.42513667e-21 -2.20211170e-21
#   2.12424985e-21  2.28448872e-21  2.72658424e-21 -2.68259891e-21
#   2.08668850e-21  2.36493698e-21],
#                  best_fitness=1.6681308482213344e-40,
#                  start_time=2023-11-02 22:31:33,
#                  end_time=2023-11-02 22:31:33>

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
