# %%
from matplotlib import pyplot as plt
 
from src.problem import unimodal
from src.ioas.SMA import SMA

# %%
sphere_solution = SMA(problem=unimodal.SphereBenchmark(dim=50), population_size=50, maximum_iterations=500).solve()

# %%
sphere_solution
# Out:
#         Solution<problem=Sphere,
#                  best_position=[-2.64789127e-168  3.50411192e-176 -1.32867359e-165 -6.71168687e-184
#  -6.25375682e-175 -1.32864956e-164 -1.01416497e-168  1.49843874e-170
#  -1.77382645e-172 -6.36215019e-164 -1.43144950e-167  1.47123460e-164
#  -4.38592607e-176 -5.71234885e-163  6.74900821e-172 -2.84812986e-179
#   1.74244243e-176 -2.18204331e-171  1.27382218e-179 -1.19263906e-172
#   3.37343950e-186 -5.23314492e-172 -2.15789744e-179 -2.10334271e-181
#  -2.48537247e-164  3.04079592e-164  8.68623473e-172 -5.65210842e-169
#   4.23867434e-167 -6.80513148e-174 -1.83454192e-169 -6.74141642e-176
#   3.26816484e-168 -1.06212914e-170  6.81149234e-173  1.50767913e-177
#   2.19901228e-170 -5.37574344e-165 -2.55197334e-164  8.10793162e-179
#  -2.38093875e-165 -2.41441020e-173  1.38017908e-167  1.16692688e-168
#   3.52033365e-165  1.29578034e-168  1.27194973e-167  1.33346406e-165
#   9.26049594e-165  7.47882285e-172],
#                  best_fitness=0.0,
#                  start_time=2023-11-02 16:30:20,
#                  end_time=2023-11-02 16:30:21>

# %%
plt.yscale('log')
plt.plot(sphere_solution.iteration_curve)
